# %%
# Import Dependencies
import numpy as np 
import pandas as pd

# %%
# Import csv data
chilis_data = pd.read_csv('Menus/Chilis.csv')
chilis = chilis_data.copy()

# %%
chilis_data
# Out:
#                            dish_name  cross_contam  egg  fish  milk  peanut  \
# 0             Awesome Blossom Petals           1.0  1.0   NaN   1.0     NaN
# 1           Boneless Wings - Buffalo           1.0  1.0   1.0   1.0     NaN
# 2    Boneless Wings - Honey Chipotle           1.0  1.0   NaN   1.0     NaN
# 3         Boneless Wings - House BBQ           1.0  1.0   NaN   1.0     NaN
# 4    Boneless Wings - Mango-Habanero           1.0  1.0   NaN   1.0     NaN
# ..                               ...           ...  ...   ...   ...     ...
# 231             Honey Chipotle Sauce           NaN  NaN   NaN   NaN     NaN
# 232                          Pickles           NaN  NaN   NaN   NaN     NaN
# 233                            Salsa           NaN  NaN   NaN   NaN     NaN
# 234                       Sour Cream           NaN  NaN   NaN   1.0     NaN
# 235                       Wing Sauce           NaN  NaN   1.0   NaN     NaN
#
#      shellfish  soy  treenuts  gluten veg/vgn dish_type
# 0          NaN  1.0       NaN     1.0      VT       App
# 1          NaN  1.0       NaN     1.0     NaN       App
# 2          NaN  1.0       NaN     1.0     NaN       App
# 3          NaN  1.0       NaN     1.0     NaN       App
# 4          NaN  1.0       NaN     1.0     NaN       App
# ..         ...  ...       ...     ...     ...       ...
# 231        NaN  NaN       NaN     NaN      VT   add_ons
# 232        NaN  NaN       NaN     NaN      VG   add_ons
# 233        NaN  NaN       NaN     NaN      VG   add_ons
# 234        NaN  NaN       NaN     NaN      VT   add_ons
# 235        NaN  NaN       NaN     NaN     NaN   add_ons
#
# [236 rows x 12 columns]

# %%
# Place holder for testing dataset outside the function
# raw_dataset = chilis_data.copy()

# %%
# Dish Data ETL Function
def allergenETL(dataset):
    # Ensure all columns are present and are FALSE if not present
    column_names = dataset.columns.values.tolist()

    # Define column types: 
    all_cols = ['dsish_id', 'dish_name', 'restaurant_id', 'restaurant_name', 'dish_type', 'ingredients', 'modifiable', 'cross_contam', 'vegan', 'vegetarian', 'gluten', 'dairy', 'tree_nuts', 'seeds', 'nightshades', 'egg', 'fish', 'peanut', 'shellfish', 'molllusks', 'legumes', 'garlic', 'soy', 'corn', 'wheat', 'barley', 'rye', 'sesame', 'coffee', 'buckwheat', 'lupin', 'mustard', 'celery', 'oat',	'rice',	'acerloa', 'apple', 'apricot', 'banana', 'cherry',	'dates', 'fig', 'grape', 'kiwi', 'lychee', 'mango', 'melon', 'orange', 'peach', 'pear', 'persimmon', 'pineapple', 'pomegranate', 'prune', 'strawberry', 'tomato', 'chickpea', 'lentil', 'pea', 'asparagus', 'avocado', 'bell_pepper', 'cabbage', 'carrot', 'lettuce', 'potato', 'pumpkin', 'turnip', 'zucchini', 'almond', 'brazil_nut', 'cashew', 'chestnut', 'hazelnut', 'macadamia', 'pecan', 'pine_nut', 'pistachio', 'walnut', 'mustard_seed', 'poppy_seed', 'pumpkin_seed', 'sunflower_seed', 'cow_milk', 'goat_milk', 'sheep_milk', 'alaska_pollack', 'carp', 'cod', 'dogfish', 'mackeral', 'salmon', 'sole', 'tuna','crustacean', 'crab', 'lobster', 'shrimp', 'abalone', 'horned_turban', 'limpet', 'marine_snail', 'mussel', 'octopus', 'oyster', 'scallop', 'squid', 'whelk', 'beef', 'chicken', 'frog', 'honey', 'mushroom', 'mycoprotein']

    # Boolean columns
    bool_cols = ['modifiable', 'cross_contam', 'vegan', 'vegetarian', 'gluten', 'dairy', 'tree_nuts', 'seeds', 'nightshades', 'egg', 'fish', 'peanut', 'shellfish', 'molllusks', 'legumes', 'garlic', 'soy', 'corn', 'wheat', 'barley', 'rye', 'sesame', 'coffee', 'buckwheat', 'lupin', 'mustard', 'celery', 'oat',	'rice',	'acerloa', 'apple', 'apricot', 'banana', 'cherry',	'dates', 'fig', 'grape', 'kiwi', 'lychee', 'mango', 'melon', 'orange', 'peach', 'pear', 'persimmon', 'pineapple', 'pomegranate', 'prune', 'strawberry', 'tomato', 'chickpea', 'lentil', 'pea', 'asparagus', 'avocado', 'bell_pepper', 'cabbage', 'carrot', 'lettuce', 'potato', 'pumpkin', 'turnip', 'zucchini', 'almond', 'brazil_nut', 'cashew', 'chestnut', 'hazelnut', 'macadamia', 'pecan', 'pine_nut', 'pistachio', 'walnut', 'mustard_seed', 'poppy_seed', 'pumpkin_seed', 'sunflower_seed', 'cow_milk', 'goat_milk', 'sheep_milk', 'alaska_pollack', 'carp', 'cod', 'dogfish', 'mackeral', 'salmon', 'sole', 'tuna','crustacean', 'crab', 'lobster', 'shrimp', 'abalone', 'horned_turban', 'limpet', 'marine_snail', 'mussel', 'octopus', 'oyster', 'scallop', 'squid', 'whelk', 'beef', 'chicken', 'frog', 'honey', 'mushroom', 'mycoprotein'] 

    # Integer columns
    int_cols = ['dsish_id', 'restaurant_id']

    # Object columns
    obj_cols = ['dish_name', 'restaurant_name', 'dish_type', 'ingredients']

    # Create the missing columns with the correct types
    for column in bool_cols:
        if column not in column_names:
            dataset[column] = False
        else: pass
    
    for column in int_cols:
        if column not in column_names:
         dataset[column] = np.nan
        #  dataset[column].astype(int)
        else: pass

    for column in obj_cols:
        if column not in column_names:
            dataset[column] = ''
            dataset[column].astype(object)
        else: pass

    # Order Columns
    dataset = dataset[all_cols]

    # Fill NA with FALSE
    # dataset.fillna(False, inplace=True)

    # Change 1.0 to TRUE
    for column in column_names:
        dataset[column] = np.where((dataset[column] == 1.0), True, dataset[column])
    
    # # Change all non-boolean columns to boolean
    # for column in bool_cols:
    #     if dataset[column].dtype != bool:
    #         dataset[column] = dataset[column].astype(bool)
    #     else: pass

    return dataset

# %%
# dataset = allergenETL(chilis_data)
dataset = allergenETL(chilis)
# Out:
# /Users/colinbartoe/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/colinbartoe/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/colinbartoe/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/colinbartoe/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'milk'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-d7b8d8ff0959> in <module>
#       1 # dataset = allergenETL(chilis_data)
# ----> 2 dataset = allergenETL(chilis)
#
# <ipython-input-13-c70db41de5c8> in allergenETL(dataset)
#      42     # Change 1.0 to TRUE
#      43     for column in column_names:
# ---> 44         dataset[column] = np.where((dataset[column] == 1.0), True, dataset[column])
#      45
#      46     # # Change all non-boolean columns to boolean
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'milk'

# %%
dataset
# Out:
#      dsish_id                        dish_name  restaurant_id restaurant_name  \
# 0         NaN           Awesome Blossom Petals            NaN
# 1         NaN         Boneless Wings - Buffalo            NaN
# 2         NaN  Boneless Wings - Honey Chipotle            NaN
# 3         NaN       Boneless Wings - House BBQ            NaN
# 4         NaN  Boneless Wings - Mango-Habanero            NaN
# ..        ...                              ...            ...             ...
# 231       NaN             Honey Chipotle Sauce            NaN
# 232       NaN                          Pickles            NaN
# 233       NaN                            Salsa            NaN
# 234       NaN                       Sour Cream            NaN
# 235       NaN                       Wing Sauce            NaN
#
#     dish_type ingredients  modifiable  cross_contam  vegan  vegetarian  ...  \
# 0         App                   False           1.0  False       False  ...
# 1         App                   False           1.0  False       False  ...
# 2         App                   False           1.0  False       False  ...
# 3         App                   False           1.0  False       False  ...
# 4         App                   False           1.0  False       False  ...
# ..        ...         ...         ...           ...    ...         ...  ...
# 231   add_ons                   False           NaN  False       False  ...
# 232   add_ons                   False           NaN  False       False  ...
# 233   add_ons                   False           NaN  False       False  ...
# 234   add_ons                   False           NaN  False       False  ...
# 235   add_ons                   False           NaN  False       False  ...
#
#      oyster  scallop  squid  whelk   beef  chicken   frog  honey  mushroom  \
# 0     False    False  False  False  False    False  False  False     False
# 1     False    False  False  False  False    False  False  False     False
# 2     False    False  False  False  False    False  False  False     False
# 3     False    False  False  False  False    False  False  False     False
# 4     False    False  False  False  False    False  False  False     False
# ..      ...      ...    ...    ...    ...      ...    ...    ...       ...
# 231   False    False  False  False  False    False  False  False     False
# 232   False    False  False  False  False    False  False  False     False
# 233   False    False  False  False  False    False  False  False     False
# 234   False    False  False  False  False    False  False  False     False
# 235   False    False  False  False  False    False  False  False     False
#
#      mycoprotein
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 231        False
# 232        False
# 233        False
# 234        False
# 235        False
#
# [236 rows x 114 columns]

# %%
dataset.info(verbose=True)
dataset.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 114 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   dsish_id         float64
#  1   dish_name        object
#  2   restaurant_id    float64
#  3   restaurant_name  object
#  4   dish_type        object
#  5   ingredients      object
#  6   modifiable       bool
#  7   cross_contam     float64
#  8   vegan            bool
#  9   vegetarian       bool
#  10  gluten           float64
#  11  dairy            bool
#  12  tree_nuts        bool
#  13  seeds            bool
#  14  nightshades      bool
#  15  egg              float64
#  16  fish             float64
#  17  peanut           float64
#  18  shellfish        float64
#  19  molllusks        bool
#  20  legumes          bool
#  21  garlic           bool
#  22  soy              float64
#  23  corn             bool
#  24  wheat            bool
#  25  barley           bool
#  26  rye              bool
#  27  sesame           bool
#  28  coffee           bool
#  29  buckwheat        bool
#  30  lupin            bool
#  31  mustard          bool
#  32  celery           bool
#  33  oat              bool
#  34  rice             bool
#  35  acerloa          bool
#  36  apple            bool
#  37  apricot          bool
#  38  banana           bool
#  39  cherry           bool
#  40  dates            bool
#  41  fig              bool
#  42  grape            bool
#  43  kiwi             bool
#  44  lychee           bool
#  45  mango            bool
#  46  melon            bool
#  47  orange           bool
#  48  peach            bool
#  49  pear             bool
#  50  persimmon        bool
#  51  pineapple        bool
#  52  pomegranate      bool
#  53  prune            bool
#  54  strawberry       bool
#  55  tomato           bool
#  56  chickpea         bool
#  57  lentil           bool
#  58  pea              bool
#  59  asparagus        bool
#  60  avocado          bool
#  61  bell_pepper      bool
#  62  cabbage          bool
#  63  carrot           bool
#  64  lettuce          bool
#  65  potato           bool
#  66  pumpkin          bool
#  67  turnip           bool
#  68  zucchini         bool
#  69  almond           bool
#  70  brazil_nut       bool
#  71  cashew           bool
#  72  chestnut         bool
#  73  hazelnut         bool
#  74  macadamia        bool
#  75  pecan            bool
#  76  pine_nut         bool
#  77  pistachio        bool
#  78  walnut           bool
#  79  mustard_seed     bool
#  80  poppy_seed       bool
#  81  pumpkin_seed     bool
#  82  sunflower_seed   bool
#  83  cow_milk         bool
#  84  goat_milk        bool
#  85  sheep_milk       bool
#  86  alaska_pollack   bool
#  87  carp             bool
#  88  cod              bool
#  89  dogfish          bool
#  90  mackeral         bool
#  91  salmon           bool
#  92  sole             bool
#  93  tuna             bool
#  94  crustacean       bool
#  95  crab             bool
#  96  lobster          bool
#  97  shrimp           bool
#  98  abalone          bool
#  99  horned_turban    bool
#  100 limpet           bool
#  101 marine_snail     bool
#  102 mussel           bool
#  103 octopus          bool
#  104 oyster           bool
#  105 scallop          bool
#  106 squid            bool
#  107 whelk            bool
#  108 beef             bool
#  109 chicken          bool
#  110 frog             bool
#  111 honey            bool
#  112 mushroom         bool
#  113 mycoprotein      bool
# dtypes: bool(101), float64(9), object(4)
# memory usage: 47.4+ KB
# dsish_id           float64
# dish_name           object
# restaurant_id      float64
# restaurant_name     object
# dish_type           object
#                     ...
# chicken               bool
# frog                  bool
# honey                 bool
# mushroom              bool
# mycoprotein           bool
# Length: 114, dtype: object

# %%
raw_dataset

# %%
chilis = chilis.astype({'cross_contamination': bool, 'egg': bool, 'fish': bool, 'milk': bool, 'peanut': bool, 'shellfish': bool, 'soy': bool, 'treenuts': bool, 'gluten': bool, 'veg/vgn': bool})
# chilis['cross_contamination'] = chilis['cross_contamination'].astype(bool)

chilis.dtypes

# %%
chilis

# %%
output_file = "chilis_data_final.csv"
chilis.to_csv(output_file, index_label = 'dishID')
